# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
y= range(10,15)
df = pd.DataFrame(x,y,)

# %%
df
# Out:
#     0
# 10  1
# 11  2
# 12  3
# 13  4
# 14  5

# %%
plt.plot(df.index, df[0])
